# %%
import numpy as np
import seaborn as sns
from pca import pca, standardizeData
import pandas as pd
    
test_Data = np.random.randint(1, 50, (5,10))
print(test_Data)
# Out:
# [[29 19 37 42  3  2  1 41  1 17]
#  [ 2 14 24 43 22 30 23 42 36  3]
#  [ 5 30 48 20  8 20 14 14 40 15]
#  [ 1 18 44 19 35 21 38  4 13 18]
#  [26 17 29 14 46 13 21 48 21 44]]

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler(copy=True)
# scaler.fit(test_Data)
# scaledData = scaler.transform(test_Data)
scaledData = standardizeData(test_Data)
pca_util = PCA(n_components=2)
result = pca_util.fit_transform(scaledData)
print(result)
df = pd.DataFrame(data=result)
ax = sns.scatterplot(data=df, x=0, y=1)

ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
# Out:
# [[ 2.92767558 -1.73326496]
#  [-0.69118831  1.02124556]
#  [-1.78886472 -2.12637128]
#  [-1.9373452   0.65709087]
#  [ 1.48972266  2.18129981]]
# Text(0, 0.5, 'PC2')

# %%
values, vectors, variance, projectedData, covMatrix = pca(2, test_Data)

# print(values)
# print(vectors)
# print(variance)
print(projectedData)

df = pd.DataFrame(data=projectedData)
ax = sns.scatterplot(data=df, x=0, y=1)
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
# Out:
# [[ 2.92767558+0.j  1.73326496+0.j]
#  [-0.69118831+0.j -1.02124556+0.j]
#  [-1.78886472+0.j  2.12637128+0.j]
#  [-1.9373452 +0.j -0.65709087+0.j]
#  [ 1.48972266+0.j -2.18129981+0.j]]
# /Users/watsonblair/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:192: ComplexWarning: Casting complex values to real discards the imaginary part
#   offsets = np.asanyarray(offsets, float)
# Text(0, 0.5, 'PC2')

# %%
sns.heatmap(covMatrix)
# Out:
# <Axes: >

# %%
"""
Test statements to ensure `homebrew` results match those produced by sklearn
"""
# Ensure data is in the same format
shapeMatches = result.shape == projectedData.shape
print(shapeMatches)


# Verify values match
valuesMatch = np.round(abs(result), 9) == np.round(abs(projectedData), 9)
print(valuesMatch)
# note that signage of the value is arbitrary
# precision to 9 decimal places is close enough.
# Out:
# True
# [[ True  True]
#  [ True  True]
#  [ True  True]
#  [ True  True]
#  [ True  True]]
